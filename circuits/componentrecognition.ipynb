# %% [markdown]
# # Circuit Component Schematic Recognition for Resistors and Capacitors

# %% [markdown]
# We are currently using a <b>KNearestNeighbors Classifier</b> on <b>2</b> circuit components.
#
# The paper, <a href="http://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=860185">Machine Recognition of Hand-Drawn Circuit Diagrams</a> , uses a <b>Nearest Neighbor Classifier</b> on <b>9</b> circuit components.
#
# This researcher, <a href="http://www.jacobsschool.ucsd.edu/faculty/faculty_bios/index.sfe?fmp_recid=337">Christine Alvarado</a> , has done similar hand-drawn circuit recognition.  We should definitely follow up on her scholarly articles.
#
# <a href="http://nbviewer.ipython.org/github/vanzaj/pyconsg2013-tut/blob/master/ipynb/04-Pandas-Scikits.ipynb">This IPython Notebook</a> using sklearn to do image processing might be helpful

# %% [markdown]
# ### Plotting Figures Inside Browser

# %%
# %matplotlib inline

# %% [markdown]
# ### Imports

# %%
# SmarterBoards Software Design Spring 2014 Final Project
# An affiliate of Lazy Man Notes - Olin Project, Inc.
# Doyung Lee and Ryan Louie 

# -*- coding: utf-8 -*-
import os
import sys

import Image
from scipy import misc
from skimage import io, transform, exposure
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier

from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Debugging Linux vs Windows Compatibility

# %%
OS = os.name # 'nt' if in Windows 7

if OS == 'nt':
    TRAIN_DATA_DIR = os.path.join(os.path.abspath('.'),'data\\')
else:
    TRAIN_DATA_DIR = os.path.join(os.path.abspath('.'),'data/')
    
NUM_TRAIN = len(os.listdir(TRAIN_DATA_DIR))

# %% [markdown]
# ### Data Loading and Formatting

# %%
def getTrainFilenames(n=75):
    filenames = os.listdir(TRAIN_DATA_DIR)
    np.random.shuffle(filenames)
    filenames = filenames[:n]
    return filenames

def isResistorFromFilename(filenames):
    is_resistor = [fn[0]=="r" for fn in filenames]
    return is_resistor

def loadImage(filename, scaler):
    image = misc.imread(filename, flatten=1) # flatten Greyscale
    image /= 255 # Normalize Pixel Values
    h = []
#     for channel in range(3):
#         tmp = image.astype(np.float64)
#         h.append(exposure.histogram(tmp[:,:,channel], nbins=10)[0])
    image = transform.resize(image, (int(scaler*1.53), int(scaler*2.56))) # small image [m,n] 153px x 256px, largeimage 1552px x 2592px
    image = image.flatten()
    h = np.array(h)
    h = h.flatten()
    return np.hstack((image, h))

def loadTrain(n, scaler=40,verbose=False):
    filenames = getTrainFilenames(n)
    is_resistor = isResistorFromFilename(filenames)
    I = []
    if verbose:
        for i in range(n):
            fn = filenames[i]
            print "loading image " + fn
            I.append(loadImage(TRAIN_DATA_DIR + fn, scaler))
    else:
        for i in range(n):
            fn = filenames[i]
            sys.stdout.write(".")
            I.append(loadImage(TRAIN_DATA_DIR + fn, scaler))      
    return I, is_resistor

# %% [markdown]
# #### Image Sizes

# %% [markdown]
# Dimensions of each image follow a <b>1.53</b> by <b>2.56</b> m x n aspect ratio.  This adheres to the landscape orientation picture we took with Doyung's smartphone camera.  We adjust the number of pixels in the horizontal and vertical pixels by a scaling factor.
#
# The challenge will be finding the right balance between having too few and too many pixels/features.  Too few, and the image is too pixelated for the classifier to pick up distinguishing features.  Too many, and the placement of the circuit component in the picture will have too drastic of an affect?

# %%
from skimage.filter import threshold_otsu
from skimage.filter import hsobel

def showcomponent(fn="capacitor100.jpg",scaler=100):
    filename = (TRAIN_DATA_DIR + fn)
    image = misc.imread(filename,1)
    image /= 255 # normalize px values
    image = transform.resize(image, (int(scaler*1.53), int(scaler*2.56))) # small image 256px x 153px, largeimage 2592px 1552px
    
    thresh = threshold_otsu(image)
    binary = image > thresh
    plt.imshow(image)
    plt.title("Scaler={}".format(scaler))
    plt.xlabel('pixels')
    plt.ylabel('pixels')
    plt.show()
    
    plt.imshow(binary)
    plt.title("Scaler={}".format(scaler))
    plt.xlabel('pixels')
    plt.ylabel('pixels')
    plt.show()
     
showcomponent(scaler=20)
showcomponent(scaler=45)
showcomponent(scaler=85)
# showcomponent(fn="capacitor33.jpg",scaler=40)

# %% [markdown]
# ## Let the machine learning workflow take affect!

# %% [markdown]
# ### Load Data and Split into Training and Test Sets

# %%
# --- Do Machine Learning!
SCALER = 30

# Load Data
I, is_resistor = loadTrain(NUM_TRAIN,SCALER)
I, is_resistor = (np.array(I), np.array(is_resistor))

# Split into Train/Test sets
I_train, I_test, is_resistor_train, is_resistor_test = train_test_split(I, is_resistor, train_size=0.7)
train_test_split?
# Out:
# ..
# ...
# ..
# ..
# ......
# ...
# ..
# ..
# ...
# ....
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ...
# ...
# ....
# ..
# ..
# ..
# ....
# ..
# ..
# ..
# ..
# ..
# ..
# ...
# ..
# ..
# ..
# ..
# ...
# ..
# ...
# ...
# ..
# ...
# ..
# ....
# ...
# ..
# ..
# ...
# ...
# ...
# ...
# ..
# ...
# ..
# .....
# ...
# ..
# ..
# ..
# ....
# ..
# ..
# ..
# ..
# ...
# ..
# ..
# ..
# ..
# .....
# ..
# ..
# ..
# ...
# ..
# ...
# ..
# ..
# ..
# ..
# ...
# ..
# ..
# ..
# ..
# ..
# ..
# ...
# ..
# ...
# ..
# ..
# ...
# ..
# ..
# ..
# ..
# ...
# ..
# ...
# ..
# ..
# ..
# .

# %% [markdown]
# ### Train Classifier

# %%
# Train Model

# clf = RandomForestClassifier()

from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=2)


clf.fit(I_train, is_resistor_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            n_neighbors=2, p=2, weights='uniform')

# %% [markdown]
# ### Evaluate Performance

# %% [markdown]
# <a href="http://www.cs.toronto.edu/~psala/ML/ML-Project.pdf"> Component Recognition Paper </a> , if we want to imporve our accuracy

# %%
# Evaluate Predictions
is_resistor_predict = clf.predict(I_test)

print "\naccuracy: " + str(accuracy_score(is_resistor_test,is_resistor_predict))
# Out:
# accuracy: 0.784810126582

# %% [markdown]
# ### Analyze Model Performance, Improve Approach

# %%
assert(len(is_resistor_predict) == len(is_resistor_test))

for i in range(len(is_resistor_predict)):
    if not (is_resistor_predict[i] == is_resistor_test[i]):
        misclassified_image = I_test[i]
        landscape_shape = (int(1.53*SCALER),int(2.56*SCALER))
        misclassified_image = misclassified_image.reshape(landscape_shape)
        
        plt.imshow(misclassified_image)
        plt.title("Misclassified Image, i = {}".format(i))
        plt.xlabel('pixels')
        plt.ylabel('pixels')
        plt.show()

# %%
# Confusion Matrix
cm = confusion_matrix(is_resistor_test, is_resistor_predict)
plt.matshow(cm)
plt.title('Confusion matrix')
plt.colorbar()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.clim(vmin=0)
plt.show()
